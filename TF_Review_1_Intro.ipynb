# %% [markdown]
# ## Intro Week 1

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

# %%
model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
xs = np.array([-1.0,  0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

# %%
model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 1ms/step - loss: 4.5844
# Epoch 2/500
# 1/1 [==============================] - 0s 926us/step - loss: 3.7779
# Epoch 3/500
# 1/1 [==============================] - 0s 2ms/step - loss: 3.1399
# Epoch 4/500
# 1/1 [==============================] - 0s 3ms/step - loss: 2.6345
# Epoch 5/500
# 1/1 [==============================] - 0s 2ms/step - loss: 2.2335
# Epoch 6/500
# 1/1 [==============================] - 0s 10ms/step - loss: 1.9147
# Epoch 7/500
# 1/1 [==============================] - 0s 4ms/step - loss: 1.6606
# Epoch 8/500
# 1/1 [==============================] - 0s 2ms/step - loss: 1.4576
# Epoch 9/500
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2948
# Epoch 10/500
# 1/1 [==============================] - 0s 3ms/step - loss: 1.1636
# Epoch 11/500
# 1/1 [==============================] - 0s 2ms/step - loss: 1.0574
# Epoch 12/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.9710
# Epoch 13/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.9001
# Epoch 14/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.8416
# Epoch 15/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.7928
# Epoch 16/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.7517
# Epoch 17/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.7167
# Epoch 18/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6867
# Epoch 19/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.6605
# Epoch 20/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6374
# Epoch 21/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6168
# Epoch 22/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.5983
# Epoch 23/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5814
# Epoch 24/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5658
# Epoch 25/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5513
# Epoch 26/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5377
# Epoch 27/500
# 1/1 [==============================] - 0s 914us/step - loss: 0.5249
# Epoch 28/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5127
# Epoch 29/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5011
# Epoch 30/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.4900
# Epoch 31/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4792
# Epoch 32/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.4688
# Epoch 33/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4588
# Epoch 34/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4490
# Epoch 35/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.4395
# Epoch 36/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4303
# Epoch 37/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4213
# Epoch 38/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4125
# Epoch 39/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4040
# Epoch 40/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3956
# Epoch 41/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3874
# Epoch 42/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.3794
# Epoch 43/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3716
# Epoch 44/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3639
# Epoch 45/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3564
# Epoch 46/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3491
# Epoch 47/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3419
# Epoch 48/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3348
# Epoch 49/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3280
# Epoch 50/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.3212
# Epoch 51/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3146
# Epoch 52/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3081
# Epoch 53/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3018
# Epoch 54/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2956
# Epoch 55/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2895
# Epoch 56/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2836
# Epoch 57/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2778
# Epoch 58/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2720
# Epoch 59/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2665
# Epoch 60/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2610
# Epoch 61/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2556
# Epoch 62/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2504
# Epoch 63/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2452
# Epoch 64/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2402
# Epoch 65/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2353
# Epoch 66/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2304
# Epoch 67/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2257
# Epoch 68/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2211
# Epoch 69/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2165
# Epoch 70/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2121
# Epoch 71/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2077
# Epoch 72/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2034
# Epoch 73/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1993
# Epoch 74/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1952
# Epoch 75/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1912
# Epoch 76/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1872
# Epoch 77/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1834
# Epoch 78/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1796
# Epoch 79/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1759
# Epoch 80/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1723
# Epoch 81/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1688
# Epoch 82/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1653
# Epoch 83/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1619
# Epoch 84/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1586
# Epoch 85/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1553
# Epoch 86/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1521
# Epoch 87/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1490
# Epoch 88/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1460
# Epoch 89/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1430
# Epoch 90/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1400
# Epoch 91/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1371
# Epoch 92/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1343
# Epoch 93/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1316
# Epoch 94/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1289
# Epoch 95/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1262
# Epoch 96/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1236
# Epoch 97/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1211
# Epoch 98/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1186
# Epoch 99/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1162
# Epoch 100/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1138
# Epoch 101/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1114
# Epoch 102/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1092
# Epoch 103/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1069
# Epoch 104/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1047
# Epoch 105/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1026
# Epoch 106/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1005
# Epoch 107/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0984
# Epoch 108/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0964
# Epoch 109/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0944
# Epoch 110/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0925
# Epoch 111/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0906
# Epoch 112/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0887
# Epoch 113/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0869
# Epoch 114/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0851
# Epoch 115/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0833
# Epoch 116/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0816
# Epoch 117/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0800
# Epoch 118/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0783
# Epoch 119/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0767
# Epoch 120/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0751
# Epoch 121/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0736
# Epoch 122/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0721
# Epoch 123/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0706
# Epoch 124/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0691
# Epoch 125/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0677
# Epoch 126/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0663
# Epoch 127/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0650
# Epoch 128/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0636
# Epoch 129/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0623
# Epoch 130/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0610
# Epoch 131/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0598
# Epoch 132/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0586
# Epoch 133/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0574
# Epoch 134/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0562
# Epoch 135/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0550
# Epoch 136/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0539
# Epoch 137/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0528
# Epoch 138/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0517
# Epoch 139/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0506
# Epoch 140/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0496
# Epoch 141/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0486
# Epoch 142/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0476
# Epoch 143/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0466
# Epoch 144/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0457
# Epoch 145/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0447
# Epoch 146/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0438
# Epoch 147/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0429
# Epoch 148/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0420
# Epoch 149/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0412
# Epoch 150/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0403
# Epoch 151/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0395
# Epoch 152/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0387
# Epoch 153/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0379
# Epoch 154/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0371
# Epoch 155/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0363
# Epoch 156/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0356
# Epoch 157/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0349
# Epoch 158/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0341
# Epoch 159/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0334
# Epoch 160/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0328
# Epoch 161/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0321
# Epoch 162/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0314
# Epoch 163/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0308
# Epoch 164/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0301
# Epoch 165/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0295
# Epoch 166/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0289
# Epoch 167/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0283
# Epoch 168/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0277
# Epoch 169/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0272
# Epoch 170/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0266
# Epoch 171/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0261
# Epoch 172/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0255
# Epoch 173/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0250
# Epoch 174/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0245
# Epoch 175/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0240
# Epoch 176/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0235
# Epoch 177/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0230
# Epoch 178/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0225
# Epoch 179/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0221
# Epoch 180/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0216
# Epoch 181/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0212
# Epoch 182/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0207
# Epoch 183/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0203
# Epoch 184/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0199
# Epoch 185/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0195
# Epoch 186/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0191
# Epoch 187/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0187
# Epoch 188/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0183
# Epoch 189/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0179
# Epoch 190/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0176
# Epoch 191/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0172
# Epoch 192/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0169
# Epoch 193/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0165
# Epoch 194/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0162
# Epoch 195/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0158
# Epoch 196/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0155
# Epoch 197/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0152
# Epoch 198/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0149
# Epoch 199/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0146
# Epoch 200/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0143
# Epoch 201/500
# 1/1 [==============================] - 0s 946us/step - loss: 0.0140
# Epoch 202/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0137
# Epoch 203/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0134
# Epoch 204/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0131
# Epoch 205/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0129
# Epoch 206/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0126
# Epoch 207/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0123
# Epoch 208/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0121
# Epoch 209/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0118
# Epoch 210/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0116
# Epoch 211/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0114
# Epoch 212/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0111
# Epoch 213/500
# 1/1 [==============================] - 0s 918us/step - loss: 0.0109
# Epoch 214/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0107
# Epoch 215/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0105
# Epoch 216/500
# 1/1 [==============================] - 0s 935us/step - loss: 0.0102
# Epoch 217/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0100
# Epoch 218/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0098
# Epoch 219/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0096
# Epoch 220/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0094
# Epoch 221/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0092
# Epoch 222/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0090
# Epoch 223/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0089
# Epoch 224/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0087
# Epoch 225/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0085
# Epoch 226/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0083
# Epoch 227/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0082
# Epoch 228/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0080
# Epoch 229/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0078
# Epoch 230/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0077
# Epoch 231/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0075
# Epoch 232/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0073
# Epoch 233/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0072
# Epoch 234/500
# 1/1 [==============================] - 0s 913us/step - loss: 0.0071
# Epoch 235/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0069
# Epoch 236/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0068
# Epoch 237/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0066
# Epoch 238/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0065
# Epoch 239/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0064
# Epoch 240/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 241/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0061
# Epoch 242/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0060
# Epoch 243/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0058
# Epoch 244/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0057
# Epoch 245/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0056
# Epoch 246/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0055
# Epoch 247/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0054
# Epoch 248/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0053
# Epoch 249/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0052
# Epoch 250/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0051
# Epoch 251/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0050
# Epoch 252/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0049
# Epoch 253/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0048
# Epoch 254/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0047
# Epoch 255/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0046
# Epoch 256/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0045
# Epoch 257/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0044
# Epoch 258/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0043
# Epoch 259/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0042
# Epoch 260/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0041
# Epoch 261/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0040
# Epoch 262/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0039
# Epoch 263/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 264/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0038
# Epoch 265/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0037
# Epoch 266/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0036
# Epoch 267/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0036
# Epoch 268/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0035
# Epoch 269/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0034
# Epoch 270/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0033
# Epoch 271/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0033
# Epoch 272/500
# 1/1 [==============================] - 0s 984us/step - loss: 0.0032
# Epoch 273/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0031
# Epoch 274/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0031
# Epoch 275/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0030
# Epoch 276/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0029
# Epoch 277/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0029
# Epoch 278/500
# 1/1 [==============================] - 0s 811us/step - loss: 0.0028
# Epoch 279/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0028
# Epoch 280/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0027
# Epoch 281/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0027
# Epoch 282/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0026
# Epoch 283/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0026
# Epoch
500
# 1/1 [==============================] - 0s 3ms/step - loss: 3.3323e-05
# Epoch 493/500
# 1/1 [==============================] - 0s 1ms/step - loss: 3.2639e-05
# Epoch 494/500
# 1/1 [==============================] - 0s 2ms/step - loss: 3.1968e-05
# Epoch 495/500
# 1/1 [==============================] - 0s 1ms/step - loss: 3.1312e-05
# Epoch 496/500
# 1/1 [==============================] - 0s 1ms/step - loss: 3.0669e-05
# Epoch 497/500
# 1/1 [==============================] - 0s 2ms/step - loss: 3.0038e-05
# Epoch 498/500
# 1/1 [==============================] - 0s 2ms/step - loss: 2.9422e-05
# Epoch 499/500
# 1/1 [==============================] - 0s 1ms/step - loss: 2.8817e-05
# Epoch 500/500
# 1/1 [==============================] - 0s 2ms/step - loss: 2.8224e-05

# %%
print(model.predict([10.0]))
# Out:
# [[18.9845]]

# %% [markdown]
# ## Intro Week 2 Computer Vision

# %%
import tensorflow as tf
from tensorflow import keras
print(tf.__version__)
# Out:
# 2.2.0

# %%
fashion_mnist = keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# %%
import matplotlib.pyplot as plt
plt.imshow(train_images[42])
print(train_labels[42])
#print(train_images[42])
# Out:
# 9

# %%
# Normalize
train_images = train_images / 255
test_images = test_images / 255

# %% [markdown]
# Sequential: That defines a SEQUENCE of layers in the neural network
#
# Flatten: Remember earlier where our images were a square, when you printed them out? Flatten just takes that square and turns it into a 1 dimensional set.
#
# Dense: Adds a layer of neurons
#
# Each layer of neurons need an activation function to tell them what to do. There's lots of options, but just use these for now.
#
# Relu effectively means "If X>0 return X, else return 0" -- so what it does it it only passes values 0 or greater to the next layer in the network.
#
# Softmax takes a set of values, and effectively picks the biggest one, so, for example, if the output of the last layer looks like [0.1, 0.1, 0.05, 0.1, 9.5, 0.1, 0.05, 0.05, 0.05], it saves you from fishing through it looking for the biggest value, and turns it into [0,0,0,0,1,0,0,0,0] -- The goal is to save a lot of coding!

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape = (28, 28)), # input image of 28x28 flattened
    keras.layers.Dense(128, activation=tf.nn.relu),
    keras.layers.Dense(10, activation=tf.nn.softmax) # softmax for the 10 classes
])

# %%
#model.compile(optimizer = tf.optimizers.Adam(), 
#              loss = "sparse_categorical_crossentropy")
#model.fit(train_images, train_labels, epochs = 5)

# %%
# Needed to update from tf v2 to v2.2 with
# (base) tf_review $ pip install --upgrade tensorflow
model.compile(optimizer = tf.optimizers.Adam(),
              loss = 'sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(train_images, train_labels, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.5040 - accuracy: 0.8241
# Epoch 2/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.3773 - accuracy: 0.8631
# Epoch 3/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.3348 - accuracy: 0.8780
# Epoch 4/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.3139 - accuracy: 0.8846
# Epoch 5/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2965 - accuracy: 0.8902

# %%
model.evaluate(test_images, test_labels)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.3441 - accuracy: 0.8777
# [0.34407538175582886, 0.8776999711990356]

# %% [markdown]
# ### Callback

# %%
class myCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs = {}):
        if(logs.get('loss') < 0.4):
            print("\nLoss is below 0.4. Cancel training.")
            self.model.stop_training = True

# %%
callback = myCallback()
model.fit(train_images, train_labels, epochs=5, callbacks = [callback])
# Out:
# Epoch 1/5
# 1856/1875 [============================>.] - ETA: 0s - loss: 0.2813 - accuracy: 0.8952
# Loss is below 0.4. Cancel training.
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2813 - accuracy: 0.8953

# %% [markdown]
# ## Intro Week 3 - CNN

# %% [markdown]
# ### Basic CNN

# %%
model = tf.keras.models.Sequential([
    # Newly added Convolution layers
    tf.keras.layers.Conv2D(64, (3, 3), activation = 'relu', input_shape = (28,28,1)), # 64 3x3 filters. Input image 28x28 with 1 channel (grey scale)
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(64, (3, 3), activation = 'relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    
    # Next 3 layers are as before
    keras.layers.Flatten(),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(10, activation='softmax') # softmax for the 10 classes

])

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 26, 26, 64)        640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 13, 13, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 11, 11, 64)        36928
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 1600)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               204928
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 243,786
# Trainable params: 243,786
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# The training data needed to be reshaped. That's because the first convolution expects a single tensor containing everything, so instead of 60,000 28x28x1 items in a list, we have a single 4D list that is 60,000x28x28x1, and the same for the test images. If you don't do this, you'll get an error when training as the Convolutions do not recognize the shape.

# %%
mnist = tf.keras.datasets.fashion_mnist
(training_images, training_labels), (test_images, test_labels) = mnist.load_data()
training_images=training_images.reshape(60000, 28, 28, 1)
training_images=training_images / 255.0
test_images = test_images.reshape(10000, 28, 28, 1)
test_images=test_images/255.0

# %%
model.fit(training_images, training_labels, epochs=5)
test_loss = model.evaluate(test_images, test_labels)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 50s 27ms/step - loss: 0.4446 - accuracy: 0.8383
# Epoch 2/5
# 1875/1875 [==============================] - 50s 27ms/step - loss: 0.2967 - accuracy: 0.8921
# Epoch 3/5
# 1875/1875 [==============================] - 49s 26ms/step - loss: 0.2514 - accuracy: 0.9074
# Epoch 4/5
# 1875/1875 [==============================] - 46s 24ms/step - loss: 0.2164 - accuracy: 0.9194
# Epoch 5/5
# 1875/1875 [==============================] - 51s 27ms/step - loss: 0.1898 - accuracy: 0.9296
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2521 - accuracy: 0.9101

# %% [markdown]
# ### Visualize CNN

# %%
print(test_labels[:100])
# Out:
# [9 2 1 1 6 1 4 6 5 7 4 5 7 3 4 1 2 4 8 0 2 5 7 9 1 4 6 0 9 3 8 8 3 3 8 0 7
#  5 7 9 6 1 3 7 6 7 2 1 2 2 4 4 5 8 2 2 8 4 8 0 7 7 8 5 1 1 2 3 9 8 7 0 2 6
#  2 3 1 2 8 4 1 8 5 9 5 0 3 2 0 6 5 3 6 7 1 8 0 1 4 2]

# %%
import matplotlib.pyplot as plt
f, axarr = plt.subplots(3,4)
FIRST_IMAGE=0
SECOND_IMAGE=23
THIRD_IMAGE=28
CONVOLUTION_NUMBER = 1 # I think this is the nth filter, so can be 0 to 63.
from tensorflow.keras import models
layer_outputs = [layer.output for layer in model.layers] # Get layers out of model defined above.
activation_model = tf.keras.models.Model(inputs = model.input, outputs = layer_outputs)
for x in range(0,4):
  f1 = activation_model.predict(test_images[FIRST_IMAGE].reshape(1, 28, 28, 1))[x]
  axarr[0,x].imshow(f1[0, : , :, CONVOLUTION_NUMBER], cmap='inferno')
  axarr[0,x].grid(False)
  f2 = activation_model.predict(test_images[SECOND_IMAGE].reshape(1, 28, 28, 1))[x]
  axarr[1,x].imshow(f2[0, : , :, CONVOLUTION_NUMBER], cmap='inferno')
  axarr[1,x].grid(False)
  f3 = activation_model.predict(test_images[THIRD_IMAGE].reshape(1, 28, 28, 1))[x]
  axarr[2,x].imshow(f3[0, : , :, CONVOLUTION_NUMBER], cmap='inferno')
  axarr[2,x].grid(False)

# %% [markdown]
# ### Experiment with Convolution and Pooling
#
# https://lodev.org/cgtutor/filtering.html

# %%
import cv2
import numpy as np
from scipy import misc
i = misc.ascent()

# %%
import matplotlib.pyplot as plt
plt.grid(False)
plt.gray()
plt.axis('off')
plt.imshow(i)
plt.show()

# %%
i_transformed = np.copy(i)
size_x = i_transformed.shape[0]
size_y = i_transformed.shape[1]

# %%
# Create a filter as a 3x3 array

# This filter detects edges nicely
# It creates a convolution that only passes through sharp edges and straight
# lines.

#Experiment with different values for fun effects.
#filter = [ [0, 1, 0], [1, -4, 1], [0, 1, 0]]

# A couple more filters to try for fun!
filter = [ [-1, -2, -1], [0, 0, 0], [1, 2, 1]]
#filter = [ [-1, 0, 1], [-2, 0, 2], [-1, 0, 1]]

# If all the digits in the filter don't add up to 0 or 1, you 
# should probably do a weight to get it to do so
# so, for example, if your weights are 1,1,1 1,2,1 1,1,1
# They add up to 10, so you would set a weight of .1 if you want to normalize them
weight  = 1

# %% [markdown]
# Now let's create a convolution. We will iterate over the image, leaving a 1 pixel margin, and multiply out each of the neighbors of the current pixel by the value defined in the filter.
#
# i.e. the current pixel's neighbor above it and to the left will be multiplied by the top left item in the filter etc. etc. We'll then multiply the result by the weight, and then ensure the result is in the range 0-255
#
# Finally we'll load the new value into the transformed image.

# %%
for x in range(1,size_x-1):
    for y in range(1,size_y-1):
        convolution = 0.0
        convolution = convolution + (i[x - 1, y-1] * filter[0][0])
        convolution = convolution + (i[x, y-1] * filter[0][1])
        convolution = convolution + (i[x + 1, y-1] * filter[0][2])
        convolution = convolution + (i[x-1, y] * filter[1][0])
        convolution = convolution + (i[x, y] * filter[1][1])
        convolution = convolution + (i[x+1, y] * filter[1][2])
        convolution = convolution + (i[x-1, y+1] * filter[2][0])
        convolution = convolution + (i[x, y+1] * filter[2][1])
        convolution = convolution + (i[x+1, y+1] * filter[2][2])
        convolution = convolution * weight
        if(convolution<0):
            convolution=0
        if(convolution>255):
            convolution=255
        i_transformed[x, y] = convolution

# %%
# Plot the image. Note the size of the axes -- they are 512 by 512
plt.gray()
plt.grid(False)
plt.imshow(i_transformed)
#plt.axis('off')
plt.show()

# %% [markdown]
# This code will show a (2, 2) pooling. The idea here is to iterate over the image, and look at the pixel and it's immediate neighbors to the right, beneath, and right-beneath. Take the largest of them and load it into the new image. Thus the new image will be 1/4 the size of the old -- with the dimensions on X and Y being halved by this process. You'll see that the features get maintained despite this compression!

# %%
new_x = int(size_x/2)
new_y = int(size_y/2)
newImage = np.zeros((new_x, new_y))
for x in range(0, size_x, 2):
    for y in range(0, size_y, 2):
        pixels = []
        pixels.append(i_transformed[x, y])
        pixels.append(i_transformed[x+1, y])
        pixels.append(i_transformed[x, y+1])
        pixels.append(i_transformed[x+1, y+1])
        newImage[int(x/2),int(y/2)] = max(pixels)

# Plot the image. Note the size of the axes -- now 256 pixels instead of 512
plt.gray()
plt.grid(False)
plt.imshow(newImage)
#plt.axis('off')
plt.show()

# %% [markdown]
# ## Intro Week 4, Using Image Generator on Real Data

# %%
# !wget --no-check-certificate \
    https://storage.googleapis.com/laurencemoroney-blog.appspot.com/horse-or-human.zip \
    -O ./data/horse-or-human.zip
# Out:
# --2020-06-21 01:11:07--  https://storage.googleapis.com/laurencemoroney-blog.appspot.com/horse-or-human.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.217.3.208
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.217.3.208|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 149574867 (143M) [application/zip]
# Saving to: ‘./data/horse-or-human.zip’
#
# ./data/horse-or-hum 100%[===================>] 142.65M  2.80MB/s    in 58s
#
# 2020-06-21 01:12:06 (2.44 MB/s) - ‘./data/horse-or-human.zip’ saved [149574867/149574867]

# %%
# !wget --no-check-certificate \
    https://storage.googleapis.com/laurencemoroney-blog.appspot.com/validation-horse-or-human.zip \
    -O ./data/validation-horse-or-human.zip
# Out:
# --2020-06-21 01:57:48--  https://storage.googleapis.com/laurencemoroney-blog.appspot.com/validation-horse-or-human.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.217.14.240
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.217.14.240|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11480187 (11M) [application/zip]
# Saving to: ‘./data/validation-horse-or-human.zip’
#
# ./data/validation-h 100%[===================>]  10.95M  2.92MB/s    in 3.7s
#
# 2020-06-21 01:57:52 (2.92 MB/s) - ‘./data/validation-horse-or-human.zip’ saved [11480187/11480187]

# %%
import os
import zipfile

local_zip = './data/horse-or-human.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('./data/horse-or-human')

local_zip = './data/validation-horse-or-human.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('./data/validation-horse-or-human')

zip_ref.close()

# %%
# Directory with our training horse pictures
train_horse_dir = os.path.join('./data/horse-or-human/horses')

# Directory with our training human pictures
train_human_dir = os.path.join('./data/horse-or-human/humans')

# Directory with our training horse pictures
validation_horse_dir = os.path.join('./data/validation-horse-or-human/horses')

# Directory with our training human pictures
validation_human_dir = os.path.join('./data/validation-horse-or-human/humans')

# %%
train_horse_names = os.listdir(train_horse_dir)
print(train_horse_names[:10])

train_human_names = os.listdir(train_human_dir)
print(train_human_names[:10])

validation_horse_hames = os.listdir(validation_horse_dir)
print(validation_horse_hames[:10])

validation_human_names = os.listdir(validation_human_dir)
print(validation_human_names[:10])
# Out:
# ['horse43-5.png', 'horse06-5.png', 'horse20-6.png', 'horse04-7.png', 'horse41-7.png', 'horse22-4.png', 'horse19-2.png', 'horse24-2.png', 'horse37-8.png', 'horse02-1.png']
# ['human17-22.png', 'human10-17.png', 'human10-03.png', 'human07-27.png', 'human09-22.png', 'human05-22.png', 'human02-03.png', 'human02-17.png', 'human15-27.png', 'human12-12.png']
# ['horse1-204.png', 'horse2-112.png', 'horse3-498.png', 'horse5-032.png', 'horse5-018.png', 'horse1-170.png', 'horse5-192.png', 'horse1-411.png', 'horse4-232.png', 'horse3-070.png']
# ['valhuman04-20.png', 'valhuman03-01.png', 'valhuman04-08.png', 'valhuman03-15.png', 'valhuman01-04.png', 'valhuman01-10.png', 'valhuman01-11.png', 'valhuman01-05.png', 'valhuman03-14.png', 'valhuman03-00.png']

# %%
print('total training horse images:', len(os.listdir(train_horse_dir)))
print('total training human images:', len(os.listdir(train_human_dir)))
print('total validation horse images:', len(os.listdir(validation_horse_dir)))
print('total validation human images:', len(os.listdir(validation_human_dir)))
# Out:
# total training horse images: 500
# total training human images: 527
# total validation horse images: 128
# total validation human images: 128

# %%
# Now let's take a look at a few pictures to get a better sense of what they look like. 
# First, configure the matplot parameters:

# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Parameters for our graph; we'll output images in a 4x4 configuration
nrows = 4
ncols = 4

# Index for iterating over images
pic_index = 0

# %%
# Now, display a batch of 8 horse and 8 human pictures. 
# You can rerun the cell to see a fresh batch each time:

# Set up matplotlib fig, and size it to fit 4x4 pics
fig = plt.gcf()
fig.set_size_inches(ncols * 4, nrows * 4)

pic_index += 8
next_horse_pix = [os.path.join(train_horse_dir, fname) 
                for fname in train_horse_names[pic_index-8:pic_index]]
next_human_pix = [os.path.join(train_human_dir, fname) 
                for fname in train_human_names[pic_index-8:pic_index]]

for i, img_path in enumerate(next_horse_pix+next_human_pix):
  # Set up subplot; subplot indices start at 1
  sp = plt.subplot(nrows, ncols, i + 1)
  sp.axis('Off') # Don't show axes (or gridlines)

  img = mpimg.imread(img_path)
  plt.imshow(img)

plt.show()

# %% [markdown]
# ## Building the Model

# %% [markdown]
# Note that because we are facing a two-class classification problem, i.e. a binary classification problem, we will end our network with a sigmoid activation, so that the output of our network will be a single scalar between 0 and 1, encoding the probability that the current image is class 1 (as opposed to class 0).

# %%
import tensorflow as tf

model = tf.keras.models.Sequential([
    # Note the input shape is the desired size of the image 300x300 with 3 bytes color
    # This is the first convolution
    tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(300, 300, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    # The second convolution
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    # The third convolution
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    # The fourth convolution
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    # The fifth convolution
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    # Flatten the results to feed into a DNN
    tf.keras.layers.Flatten(),
    # 512 neuron hidden layer
    tf.keras.layers.Dense(512, activation='relu'),
    # Only 1 output neuron. It will contain a value from 0-1 where 0 for 1 class ('horses') and 1 for the other ('humans')
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 298, 298, 16)      448
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 149, 149, 16)      0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 147, 147, 32)      4640
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 73, 73, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 71, 71, 64)        18496
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 35, 35, 64)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 33, 33, 64)        36928
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 14, 14, 64)        36928
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 7, 7, 64)          0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 3136)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 512)               1606144
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 1,704,097
# Trainable params: 1,704,097
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Next, we'll configure the specifications for model training. We will train our model with the binary_crossentropy loss, because it's a binary classification problem and our final activation is a sigmoid. We will use the rmsprop optimizer with a learning rate of 0.001. During training, we will want to monitor classification accuracy.
#
# NOTE: In this case, using the RMSprop optimization algorithm is preferable to stochastic gradient descent (SGD), because RMSprop automates learning-rate tuning for us. (Other optimizers, such as Adam and Adagrad, also automatically adapt the learning rate during training, and would work equally well here.)

# %%
from tensorflow.keras.optimizers import RMSprop

model.compile(loss='binary_crossentropy',
              optimizer=RMSprop(lr=0.001),
              metrics=['accuracy'])

# %% [markdown]
# ### Data Processing
# Let's set up data generators that will read pictures in our source folders, convert them to float32 tensors, and feed them (with their labels) to our network. We'll have one generator for the training images and one for the validation images. Our generators will yield batches of images of size 300x300 and their labels (binary).
#
# As you may already know, data that goes into neural networks should usually be normalized in some way to make it more amenable to processing by the network. (It is uncommon to feed raw pixels into a convnet.) In our case, we will preprocess our images by normalizing the pixel values to be in the [0, 1] range (originally all values are in the [0, 255] range).
#
# In Keras this can be done via the keras.preprocessing.image.ImageDataGenerator class using the rescale parameter. This ImageDataGenerator class allows you to instantiate generators of augmented image batches (and their labels) via .flow(data, labels) or .flow_from_directory(directory). These generators can then be used with the Keras model methods that accept data generators as inputs: fit, evaluate_generator, and predict_generator.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# All images will be rescaled by 1./255
train_datagen = ImageDataGenerator(rescale=1/255)
validation_datagen = ImageDataGenerator(rescale=1/255)

# Flow training images in batches of 128 using train_datagen generator
train_generator = train_datagen.flow_from_directory(
        './data/horse-or-human/',  # This is the source directory for training images
        target_size=(300, 300),    # All images will be resized to 150x150
        batch_size=128,
        # Since we use binary_crossentropy loss, we need binary labels
        class_mode='binary')

# Flow training images in batches of 128 using train_datagen generator
validation_generator = validation_datagen.flow_from_directory(
        './data/validation-horse-or-human/',  # This is the source directory for training images
        target_size=(300, 300),  # All images will be resized to 300x300
        batch_size=32,
        # Since we use binary_crossentropy loss, we need binary labels
        class_mode='binary')
# Out:
# Found 1027 images belonging to 2 classes.
# Found 256 images belonging to 2 classes.

# %% [markdown]
# ### Training

# %%
history = model.fit(
      train_generator,
      steps_per_epoch=8, # there are total 1204 images. 128x8 = 1024  
      epochs=15,
      verbose=1,
      validation_data = validation_generator,
      validation_steps=8)
# Out:
# Epoch 1/15
# 8/8 [==============================] - 50s 6s/step - loss: 0.0160 - accuracy: 0.9951 - val_loss: 1.6259 - val_accuracy: 0.8711
# Epoch 2/15
# 8/8 [==============================] - 52s 6s/step - loss: 0.0075 - accuracy: 0.9989 - val_loss: 1.9705 - val_accuracy: 0.8672
# Epoch 3/15
# 8/8 [==============================] - 46s 6s/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 1.8215 - val_accuracy: 0.8750
# Epoch 4/15
# 8/8 [==============================] - 47s 6s/step - loss: 0.6856 - accuracy: 0.9344 - val_loss: 2.5442 - val_accuracy: 0.6914
# Epoch 5/15
# 8/8 [==============================] - 50s 6s/step - loss: 0.0302 - accuracy: 0.9878 - val_loss: 2.1063 - val_accuracy: 0.8164
# Epoch 6/15
# 8/8 [==============================] - 43s 5s/step - loss: 0.0268 - accuracy: 0.9911 - val_loss: 4.6212 - val_accuracy: 0.7344
# Epoch 7/15
# 8/8 [==============================] - 50s 6s/step - loss: 0.0344 - accuracy: 0.9855 - val_loss: 1.9692 - val_accuracy: 0.8203
# Epoch 8/15
# 8/8 [==============================] - 44s 5s/step - loss: 0.0108 - accuracy: 0.9956 - val_loss: 2.0964 - val_accuracy: 0.8438
# Epoch 9/15
# 8/8 [==============================] - 49s 6s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 2.2221 - val_accuracy: 0.8438
# Epoch 10/15
# 8/8 [==============================] - 45s 6s/step - loss: 6.4650e-04 - accuracy: 1.0000 - val_loss: 2.3307 - val_accuracy: 0.8438
# Epoch 11/15
# 8/8 [==============================] - 42s 5s/step - loss: 5.6270e-04 - accuracy: 1.0000 - val_loss: 3.3311 - val_accuracy: 0.8008
# Epoch 12/15
# 8/8 [==============================] - 37s 5s/step - loss: 1.9538e-04 - accuracy: 1.0000 - val_loss: 2.7439 - val_accuracy: 0.8477
# Epoch 13/15
# 8/8 [==============================] - 36s 5s/step - loss: 1.4872e-04 - accuracy: 1.0000 - val_loss: 2.9120 - val_accuracy: 0.8164
# Epoch 14/15
# 8/8 [==============================] - 37s 5s/step - loss: 9.1763e-05 - accuracy: 1.0000 - val_loss: 3.8428 - val_accuracy: 0.8164
# Epoch 15/15
# 8/8 [==============================] - 36s 5s/step - loss: 4.8953e-05 - accuracy: 1.0000 - val_loss: 3.1753 - val_accuracy: 0.8477

# %% [markdown]
# ### Running the model

# %%
# put images in ./data/images/

import numpy as np
import os
from keras.preprocessing import image
# predicting images
directory = "./data/images/"
for filename in os.listdir(directory):
    #path = '/content/' + fn
    filename = directory + filename
    img = image.load_img(filename, target_size=(300, 300))
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)

    images = np.vstack([x])
    classes = model.predict(images, batch_size=10)
    print(classes[0])
    if classes[0]>0.5:
        print(filename + " is a human")
    else:
        print(filename + " is a horse")
# Out:
# [0.]
# ./data/images/eugene.jpg is a horse
# [1.]
# ./data/images/suzuki.jpg is a human

# %% [markdown]
# ### Visualizing Intermediate Representations
# Let's pick a random image from the training set, and then generate a figure where each row is the output of a layer, and each image in the row is a specific filter in that output feature map. Rerun this cell to generate intermediate representations for a variety of training images.

# %%
import numpy as np
import random
from tensorflow.keras.preprocessing.image import img_to_array, load_img

# Let's define a new Model that will take an image as input, and will output
# intermediate representations for all layers in the previous model after
# the first.
successive_outputs = [layer.output for layer in model.layers[1:]]
#visualization_model = Model(img_input, successive_outputs)
visualization_model = tf.keras.models.Model(inputs = model.input, outputs = successive_outputs)
# Let's prepare a random input image from the training set.
horse_img_files = [os.path.join(train_horse_dir, f) for f in train_horse_names]
human_img_files = [os.path.join(train_human_dir, f) for f in train_human_names]
img_path = random.choice(horse_img_files + human_img_files)

img = load_img(img_path, target_size=(300, 300))  # this is a PIL image
x = img_to_array(img)  # Numpy array with shape (150, 150, 3)
x = x.reshape((1,) + x.shape)  # Numpy array with shape (1, 150, 150, 3)

# Rescale by 1/255
x /= 255

# Let's run our image through our network, thus obtaining all
# intermediate representations for this image.
successive_feature_maps = visualization_model.predict(x)

# These are the names of the layers, so can have them as part of our plot
layer_names = [layer.name for layer in model.layers[1:]]

# Now let's display our representations
for layer_name, feature_map in zip(layer_names, successive_feature_maps):
  if len(feature_map.shape) == 4:
    # Just do this for the conv / maxpool layers, not the fully-connected layers
    n_features = feature_map.shape[-1]  # number of features in feature map
    # The feature map has shape (1, size, size, n_features)
    size = feature_map.shape[1]
    # We will tile our images in this matrix
    display_grid = np.zeros((size, size * n_features))
    for i in range(n_features):
      # Postprocess the feature to make it visually palatable
      x = feature_map[0, :, :, i]
      x -= x.mean()
      x /= x.std()
      x *= 64
      x += 128
      x = np.clip(x, 0, 255).astype('uint8')
      # We'll tile each filter into this big horizontal grid
      display_grid[:, i * size : (i + 1) * size] = x
    # Display the grid
    scale = 20. / n_features
    plt.figure(figsize=(scale * n_features, scale))
    plt.title(layer_name)
    plt.grid(False)
    plt.imshow(display_grid, aspect='auto', cmap='viridis')
# Out:
# /Users/eugenelin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:43: RuntimeWarning: invalid value encountered in true_divide

# %% [markdown]
# As you can see we go from the raw pixels of the images to increasingly abstract and compact representations. The representations downstream start highlighting what the network pays attention to, and they show fewer and fewer features being "activated"; most are set to zero. This is called "sparsity." Representation sparsity is a key feature of deep learning.
#
# These representations carry increasingly less information about the original pixels of the image, but increasingly refined information about the class of the image. You can think of a convnet (or a deep network in general) as an information distillation pipeline.
